# %% [markdown]
# # Imports

# %%
from diffusers import StableDiffusionPipeline
from utils import plot_img
import torch

# %% [markdown]
# # Parameters

# %%
finetuned_model = "./models/shane/stable_diffusion_weights/sks"
prompt = "photo of young human sks man, photorealistic, in color"

# %% [markdown]
# # Model

# %%
pipe = StableDiffusionPipeline.from_pretrained(finetuned_model, torch_dtype=torch.float16).to("cuda")

# %%
image = pipe(prompt, num_inference_steps=50, guidance_scale=7.5).images[0]
plot_img(image)
# Out:
# 100%|██████████| 50/50 [00:10<00:00,  4.95it/s]
